# %% [markdown]
# <a href="https://colab.research.google.com/github/Soniya-2025/soniya2025-training/blob/main/NETFLIX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4171bb21-07a6-4de6-95a9-4a2b426cc080" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4171bb21-07a6-4de6-95a9-4a2b426cc080">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# 'archive (2) (1).zip'  'archive (2).zip'   sample_data

# %%
# !unzip -o "archive (2).zip"
# Out:
# Archive:  archive (2).zip
#   inflating: australia.csv
#   inflating: canada.csv
#   inflating: egypt.csv
#   inflating: france.csv
#   inflating: hongkong.csv
#   inflating: india.csv
#   inflating: japan.csv
#   inflating: mexico.csv
#   inflating: south_korea.csv
#   inflating: spain.csv
#   inflating: taiwan.csv
#   inflating: thailand.csv
#   inflating: turkey.csv
#   inflating: uk.csv

# %%
# !find . -name "*.csv"
# Out:
# ./mexico.csv
# ./hongkong.csv
# ./taiwan.csv
# ./turkey.csv
# ./france.csv
# ./canada.csv
# ./thailand.csv
# ./india.csv
# ./australia.csv
# ./egypt.csv
# ./spain.csv
# ./japan.csv
# ./uk.csv
# ./south_korea.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_test.csv

# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1362/4168257801.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("netflix_titles.csv")
#       4 print(df.head())
#
# ...

# %%
import pandas as pd

df = pd.read_csv("india.csv")

print(df.head())
print(df.shape)
print(df.columns)
# Out:
#            Category: All categories
# Week               netflix: (India)
# 2015-01-11                        4
# 2015-01-18                        4
# 2015-01-25                        4
# 2015-02-01                        4
# (262, 1)
# Index(['Category: All categories'], dtype='object')

# %%
# Head
print(df.head())

# Tail
print(df.tail())

# Shape
print(df.shape)

# Length
print(len(df))

# Info
print(df.info())

# Describe
print(df.describe())

# Columns
print(df.columns)

# Data Types
print(df.dtypes)

# Missing Values
print(df.isnull().sum())

# Duplicates
print("Duplicate rows:", df.duplicated().sum())
# Out:
#            Category: All categories
# Week               netflix: (India)
# 2015-01-11                        4
# 2015-01-18                        4
# 2015-01-25                        4
# 2015-02-01                        4
#            Category: All categories
# 2019-12-08                       54
# 2019-12-15                       58
# 2019-12-22                       68
# 2019-12-29                       76
# 2020-01-05                       70
# (262, 1)
# 262
# <class 'pandas.core.frame.DataFrame'>
# Index: 262 entries, Week to 2020-01-05
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Category: All categories  262 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB
# None
#        Category: All categories
# count                       262
# unique                       64
# top                           4
# freq                         19
# ...

# %%
df = pd.read_csv("india.csv")
print(df.columns)
print(df.head())
# Out:
# Index(['Category: All categories'], dtype='object')
#            Category: All categories
# Week               netflix: (India)
# 2015-01-11                        4
# 2015-01-18                        4
# 2015-01-25                        4
# 2015-02-01                        4

# %%
print(df.isnull().sum())
# Out:
# Category: All categories    0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 198

# %%
df = df.drop_duplicates()

# %%
print(df.dtypes)
# Out:
# Category: All categories    object
# dtype: object

# %%
print(df.describe())
# Out:
#        Category: All categories
# count                        64
# unique                       64
# top            netflix: (India)
# freq                          1

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_scaled = scaler.fit_transform(df)

# %%
print(df.head())
print(df.shape)
print(df.info())
# Out:
#             Category: All categories
# Week                              63
# 2015-01-11                        24
# 2015-04-05                        34
# 2015-08-30                        45
# 2015-09-27                        54
# (64, 1)
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, Week to 2019-12-29
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Category: All categories  64 non-null     int64
# dtypes: int64(1)
# memory usage: 3.1+ KB
# None

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['Category: All categories'], dtype='object')
#             Category: All categories
# Week                              63
# 2015-01-11                        24
# 2015-04-05                        34
# 2015-08-30                        45
# 2015-09-27                        54
